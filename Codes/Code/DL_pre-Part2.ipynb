# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
from scipy import *
import sympy as sympy

# %%
x= .5 
print(x)
# Out:
# 0.5

# %%
o = np.array(2)
a = np.array([1,2,3,4,5])
b = np.array([[1,2,3], [4,5,6]])
c = np.array([[[1,2,3,4,5], [5,6,7,8,9]], [[1,2,3,4,5], [5,4,3,2,1]]])

# %%
print(a.shape)
# Out:
# (5,)

# %%
print(a.ndim)
# Out:
# 1

# %%
print(o.ndim)
print(a.ndim)
print(b.ndim)
print(c.ndim)
# Out:
# 0
# 1
# 2
# 3

# %%
arr= np.array([1,2,3,4], ndmin=1)

# %%
print(arr)
print(arr.shape)
print(arr.ndim)
# Out:
# [1 2 3 4]
# (4,)
# 1

# %%
arr = arr.reshape((2,2))

# %%
print(arr)
# Out:
# [[1 2]
#  [3 4]]

# %%
arr.ndim
# Out:
# 2

# %%
print(arr.shape)
# Out:
# (2, 2)

# %%
vals = arr.reshape((arr.shape[0], arr.shape[1]))

# %%
B = np.random.randn(2,2)
print(B)
# Out:
# [[ 0.91573881  1.13068086]
#  [ 1.39813206 -0.36849272]]

# %%
A = np.random.randn(2,2)
print(A)
# Out:
# [[-0.41205363  0.10148153]
#  [ 1.1294911   0.45407244]]

# %%
Results = A +B

# %%
print(Results)
# Out:
# [[0.50368518 1.23216238]
#  [2.52762317 0.08557972]]

# %%
Results*2
# Out:
# array([[1.00737036, 2.46432477],
#        [5.05524633, 0.17115944]])

# %%
np.matmul(A, B)
# Out:
# array([[-0.23544893, -0.50329636],
#        [ 1.66917208,  1.10977158]])

# %%
result_inv = np.linalg.inv(Results)

# %%
print(result_inv)
# Out:
# [[-0.027864    0.40118112]
#  [ 0.82297163 -0.16399542]]

# %%
A = np.arange(6).reshape((3,2))
B = np.arange(8).reshape((2,4))

# %%
print(A)
# Out:
# [[0 1]
#  [2 3]
#  [4 5]]

# %%
print(A.T)
# Out:
# [[0 2 4]
#  [1 3 5]]

# %%
I = np.identity(3, dtype=float)
print(I)
# Out:
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]

# %%
print(B.T.dot(A.T))
print('The Matrix is Identical to :')
print((A.dot(B)).T)
# Out:
# [[ 4 12 20]
#  [ 5 17 29]
#  [ 6 22 38]
#  [ 7 27 47]]
# The Matrix is Identical to :
# [[ 4 12 20]
#  [ 5 17 29]
#  [ 6 22 38]
#  [ 7 27 47]]
