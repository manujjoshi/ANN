# %%
import numpy as np
import os

# %%
u = np.array([3,4])
v = np.array([30, 40])

# %%
print(u, v)
# Out:
# [3 4] [30 40]

# %%
print(np.linalg.norm(u))
print(np.linalg.norm(v))
# Out:
# 5.0
# 50.0

# %%
def direction(x):
  return x/np.linalg.norm(x)

# %%
u_direction = direction(u)
v_direction = direction(v)

# %%
print(u_direction)
# Out:
# [0.6 0.8]

# %%
print(v_direction)
# Out:
# [0.6 0.8]

# %%
print(np.linalg.norm(u_direction))
# Out:
# 1.0

# %%
def dot_product(x, y):
  result=0
  for i in range(len(x)):
    result = result+x[i]*y[i]
  return(result)

# %%
x = [3, 5]
y= [8,3]
print(dot_product(x, y))
# Out:
# 39

# %%
import math
def geometric_dot_product(x,y,theta):
  x_norm = np.linalg.norm(x)
  y_norm = np.linalg.norm(y)
  return x_norm*y_norm*math.cos(math.radians(theta))

# %%
print(np.linalg.norm(x)*np.linalg.norm(y))
print(geometric_dot_product(x, y, theta=30))
# Out:
# 49.8196748283246
# 43.14510400960925

# %%
# 3x + 4y = 5
# 5x+7y = 8
# 8x+9y=4

# %%
a = np.array([[3,4],[5,7], [8, 9]])
b = np.array([[5], [8], [4]])

# %%
#c = np.linalg.solve(a,b)
c = np.linalg.lstsq(a,b)[0]
print(c)
# Out:
# [[-4.2585034 ]
#  [ 4.23809524]]
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.

# %%
print(8*c[0]+9*c[1])
# Out:
# [4.07482993]

# %%
c =np.array([3,4])
z=np.array([5,6])

# %%
print(c, z)
# Out:
# [3 4] [5 6]

# %%
b = list(zip(z, c))

# %%
print(b)
# Out:
# [(5, 3), (6, 4)]

# %%
print(type(b[0]))
# Out:
# <class 'tuple'>

# %%
A = np.array(b)

# %%
print(A)
print(type(A))
print(A.shape)
# Out:
# [[5 3]
#  [6 4]]
# <class 'numpy.ndarray'>
# (2, 2)

# %%
result = A+3

# %%
print(result)
# Out:
# [[8 6]
#  [9 7]]

# %%
B = np.random.randn(2,2)

# %%
print(B)
# Out:
# [[-0.39677546 -0.72644765]
#  [-1.08706025  0.23997968]]

# %%
np.matmul(A, B)
# Out:
# array([[-5.24505808, -2.91229923],
#        [-6.72889379, -3.3987672 ]])

# %%
print(A.dot(B))
print(np.dot(A, B))
# Out:
# [[-5.24505808 -2.91229923]
#  [-6.72889379 -3.3987672 ]]
# [[-5.24505808 -2.91229923]
#  [-6.72889379 -3.3987672 ]]
